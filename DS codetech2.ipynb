# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   ocean_proximity     20433 non-null  object
#  9   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   ocean_proximity     20433 non-null  object
#  9   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
#split the data
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data

# %%
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8824     -118.36     34.09                  36         1616           465.0
# 8941     -118.46     34.01                  48         1640           322.0
# 5199     -118.28     33.93                  21          847           278.0
# 12161    -117.18     33.78                   7         1697           424.0
# 9824     -121.91     36.62                  40         1292           271.0
# ...          ...       ...                 ...          ...             ...
# 10191    -117.94     33.86                  36         2824           493.0
# 4535     -118.21     34.03                  44         1550           407.0
# 14479    -117.24     32.83                  18         3109           501.0
# 14181    -117.05     32.72                  35         1777           369.0
# 936      -122.06     37.54                  20         6483          1068.0
#
#        population  households  median_income ocean_proximity  \
# 8824          773         429         2.6000       <1H OCEAN
# 8941          664         301         4.0000       <1H OCEAN
# 5199         1283         277         1.4329       <1H OCEAN
# 12161         808         354         1.3417          INLAND
# 9824          504         230         2.4750       <1H OCEAN
# ...           ...         ...            ...             ...
# 10191        1394         507         4.6477       <1H OCEAN
# 4535         1718         403         2.5268       <1H OCEAN
# 14479         949         368         7.4351      NEAR OCEAN
# 14181        1158         353         3.4107      NEAR OCEAN
# 936          3526        1060         5.0838        NEAR BAY
#
#        median_house_value
# 8824               313600
# 8941               500001
# 5199                94100
# 12161              169300
# 9824               258300
# ...                   ...
# 10191              194700
# 4535               141100
# 14479              445700
# 14181              117000
# 936                248200
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#data preprocessing
numeric_train_data = train_data.select_dtypes(include=[float, int])

from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for column in train_data.select_dtypes(include=[object]).columns:
    le = LabelEncoder()
    train_data[column] = le.fit_transform(train_data[column])
    label_encoders[column] = le

# %%
corr_matrix = numeric_train_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>],
#        [<Axes: title={'center': 'bedroom_ratio'}>,
#         <Axes: title={'center': 'household_rooms'}>, <Axes: >]],
#       dtype=object)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8824     -118.36     34.09                  36     2.126841        1.966299
# 8941     -118.46     34.01                  48     2.128596        1.913631
# 5199     -118.28     33.93                  21     2.046774        1.891788
# 12161    -117.18     33.78                   7     2.132651        1.953324
# 9824     -121.91     36.62                  40     2.099822        1.887948
# ...          ...       ...                 ...          ...             ...
# 10191    -117.94     33.86                  36     2.191236        1.974433
# 4535     -118.21     34.03                  44     2.121861        1.947518
# 14479    -117.24     32.83                  18     2.201922        1.976661
# 14181    -117.05     32.72                  35     2.138093        1.933476
# 936      -122.06     37.54                  20     2.280042        2.076246
#
#        population  households  median_income  median_house_value      0  \
# 8824     2.034911    1.954981         2.6000              313600   True
# 8941     2.014875    1.903663         4.0000              500001   True
# 5199     2.098967    1.891246         1.4329               94100   True
# 12161    2.040675    1.927472         1.3417              169300  False
# 9824     1.977486    1.862904         2.4750              258300   True
# ...           ...         ...            ...                 ...    ...
# 10191    2.109079    1.978306         4.6477              194700   True
# 4535     2.134107    1.946112         2.5268              141100   True
# 14479    2.061336    1.933085         7.4351              445700  False
# 14181    2.086332    1.927062         3.4107              117000  False
# 936      2.215741    2.075304         5.0838              248200  False
#
#            1      2      3      4  bedroom_ratio  household_rooms
# 8824   False  False  False  False       0.924516         1.087909
# 8941   False  False  False  False       0.899011         1.118158
# 5199   False  False  False  False       0.924278         1.082236
# 12161   True  False  False  False       0.915913         1.106450
# 9824   False  False  False  False       0.899099         1.127177
# ...      ...    ...    ...    ...            ...              ...
# 10191  False  False  False  False       0.901059         1.107633
# 4535   False  False  False  False       0.917835         1.090308
# 14479  False  False  False   True       0.897698         1.139072
# 14181  False  False  False   True       0.904300         1.109509
# 936    False  False   True  False       0.910617         1.098655
#
# [16346 rows x 16 columns]

# %%
#train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
#train_data

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude',y='longitude',data=train_data,hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
#feature engineering
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#linear regression model
#from sklearn.linear_model import LinearRegression
#x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
#reg=LinearRegression()
#reg.fit(x_train,y_train)
x_train.columns = x_train.columns.astype(str)

# Fit the Linear Regression model
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(train_data.columns)
# Out:
# Index([         'longitude',           'latitude', 'housing_median_age',
#               'total_rooms',     'total_bedrooms',         'population',
#                'households',      'median_income', 'median_house_value',
#                           0,                    1,                    2,
#                           3,                    4,      'bedroom_ratio',
#           'household_rooms'],
#       dtype='object')

# %%
# Check and use the correct column name for the categorical variable
if 'Ocean_Proximity' in train_data.columns:
    train_data = train_data.join(pd.get_dummies(train_data['Ocean_Proximity'])).drop(['Ocean_Proximity'], axis=1)
elif 'ocean_proximity' in train_data.columns:
    train_data = train_data.join(pd.get_dummies(train_data['ocean_proximity'])).drop(['ocean_proximity'], axis=1)
else:
    print("Column 'Ocean_Proximity' or 'ocean_proximity' not found in train_data.")
# Out:
# Column 'Ocean_Proximity' or 'ocean_proximity' not found in train_data.

# %%
test_data=x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

#train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)


test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
x_train,y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg.score(x_test,y_test)
# Out:
# -5.143292972048798
